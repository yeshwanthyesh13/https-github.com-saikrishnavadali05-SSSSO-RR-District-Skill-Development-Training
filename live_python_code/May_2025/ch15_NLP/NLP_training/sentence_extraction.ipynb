# %%
import nltk
from nltk.tokenize import sent_tokenize

text = "Hello world! This is an example. NLP is fun. Let's tokenize sentences."

# Example 1: Basic sentence tokenization
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Hello world!', 'This is an example.', 'NLP is fun.', "Let's tokenize sentences."]

# %%
# Example 2: Tokenize a paragraph with abbreviations
text2 = "Dr. Smith went to Washington. He arrived at 3 p.m. It was sunny."
print(sent_tokenize(text2))
# Out:
# ['Dr. Smith went to Washington.', 'He arrived at 3 p.m.', 'It was sunny.']

# %%
# Example 3: Using PunktSentenceTokenizer for training
from nltk.tokenize import PunktSentenceTokenizer
custom_tokenizer = PunktSentenceTokenizer(text2)
print(custom_tokenizer.tokenize(text2))
# Out:
# ['Dr. Smith went to Washington.', 'He arrived at 3 p.m. It was sunny.']

# %%
# !pip install spacy
import spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spacy
#   Downloading spacy-3.8.7-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.13-cp313-cp313-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.10-cp313-cp313-win_amd64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.6-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (2.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from spacy) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.0-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\santhosh\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.7-cp313-cp313-win_amd64.whl (13.9 MB)
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    ------ --------------------------------- 2.4/13.9 MB 11.2 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.9 MB 11.5 MB/s eta 0:00:01
#    --------------------- ------------------ 7.3/13.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------- ------------ 9.7/13.9 MB 11.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.3/13.9 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  13.9/13.9 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 13.9/13.9 MB 10.3 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp313-cp313-win_amd64.whl (39 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.13-cp313-cp313-win_amd64.whl (24 kB)
# Downloading preshed-3.0.10-cp313-cp313-win_amd64.whl (115 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp313-cp313-win_amd64.whl (630 kB)
#    ---------------------------------------- 0.0/630.6 kB ? eta -:--:--
#    ---------------------------------------- 630.6/630.6 kB 7.2 MB/s eta 0:00:00
# Downloading thinc-8.3.6-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------ --- 1.6/1.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.8 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/6.3 MB 11.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.8/6.3 MB 11.4 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.3 MB 3.6 MB/s eta 0:00:02
#    ------------------------- -------------- 3.9/6.3 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.0 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Downloading smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    ------------- -------------------------- 1.8/5.4 MB 10.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.9/5.4 MB 9.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.7/5.4 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 7.0 MB/s eta 0:00:00
# Downloading marisa_trie-1.2.1-cp313-cp313-win_amd64.whl (149 kB)
# Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl (38 kB)
# Installing collected packages: cymem, wrapt, wasabi, spacy-loggers, spacy-legacy, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, smart-open, preshed, language-data, langcodes, confection, weasel, thinc, spacy
#
#    -- -------------------------------------  1/19 [wrapt]
#    -- -------------------------------------  1/19 [wrapt]
#    -- -------------------------------------  1/19 [wrapt]
#    ---- -----------------------------------  2/19 [wasabi]
#    ---- -----------------------------------  2/19 [wasabi]
#    ---- -----------------------------------  2/19 [wasabi]
#    ---- -----------------------------------  2/19 [wasabi]
#    ------ ---------------------------------  3/19 [spacy-loggers]
#    ------ ---------------------------------  3/19 [spacy-loggers]
#    ------ ---------------------------------  3/19 [spacy-loggers]
#    -------- -------------------------------  4/19 [spacy-legacy]
#    -------- -------------------------------  4/19 [spacy-legacy]
#    -------- -------------------------------  4/19 [spacy-legacy]
#    -------- -------------------------------  4/19 [spacy-legacy]
#    -------- -------------------------------  4/19 [spacy-legacy]
#    ---------- -----------------------------  5/19 [murmurhash]
#    ---------- -----------------------------  5/19 [murmurhash]
#    ------------ ---------------------------  6/19 [marisa-trie]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    -------------- -------------------------  7/19 [cloudpathlib]
#    ---------------- -----------------------  8/19 [catalogue]
#    ------------------ ---------------------  9/19 [blis]
#    ------------------ ---------------------  9/19 [blis]
#    ------------------ ---------------------  9/19 [blis]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    --------------------- ------------------ 10/19 [srsly]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ----------------------- ---------------- 11/19 [smart-open]
#    ------------------------- -------------- 12/19 [preshed]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    --------------------------- ------------ 13/19 [language-data]
#    ----------------------------- ---------- 14/19 [langcodes]
#    ----------------------------- ---------- 14/19 [langcodes]
#    ----------------------------- ---------- 14/19 [langcodes]
#    ----------------------------- ---------- 14/19 [langcodes]
#    ------------------------------- -------- 15/19 [confection]
#    ------------------------------- -------- 15/19 [confection]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    --------------------------------- ------ 16/19 [weasel]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ----------------------------------- ---- 17/19 [thinc]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ------------------------------------- -- 18/19 [spacy]
#    ---------------------------------------- 19/19 [spacy]
#
# Successfully installed blis-1.3.0 catalogue-2.0.10 cloudpathlib-0.21.1 confection-0.1.5 cymem-2.0.11 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.13 preshed-3.0.10 smart-open-7.3.0.post1 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2
#   WARNING: The script weasel.exe is installed in 'C:\Users\SANTHOSH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\SANTHOSH\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
print([sent.text for sent in doc.sents])
# Out:
# ['Hello world!', 'This is an example.', 'NLP is fun.', "Let's tokenize sentences."]

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
# Example 5: Sentence tokenization with regex (basic)
import re
sentences_regex = re.split(r'(?<=[.!?]) +', text)
print(sentences_regex)
# Out:
# ['Hello world!', 'This is an example.', 'NLP is fun.', "Let's tokenize sentences."]

# %%
# Example 6: Tokenizing sentences with newline characters
text3 = "Hello world!\nHow are you?\nI am fine."
print(sent_tokenize(text3))
# Out:
# ['Hello world!', 'How are you?', 'I am fine.']

# %%
# Example 7: Tokenize complex sentences with quotes
text4 = 'He said, "NLP is amazing!" Did you hear that?'
print(sent_tokenize(text4))
# Out:
# ['He said, "NLP is amazing!"', 'Did you hear that?']

# %%
# Example 8: Count sentences
print(f"Number of sentences: {len(sentences)}")
# Out:
# Number of sentences: 4

# %%
# Example 9: Tokenize sentences and strip whitespace
sentences_stripped = [s.strip() for s in sentences]
print(sentences_stripped)
# Out:
# ['Hello world!', 'This is an example.', 'NLP is fun.', "Let's tokenize sentences."]

# %%
# Example 10: Sentence tokenization in other languages (e.g., German)
text_de = "Hallo Welt! Dies ist ein Beispiel."
print(sent_tokenize(text_de, language='german'))
# Out:
# ['Hallo Welt!', 'Dies ist ein Beispiel.']
